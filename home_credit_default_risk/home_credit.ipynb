# %%
# %matplotlib inline
import zipfile as zp
import pandas as pd
import os
import sklearn as sk
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
zip_ref=zp.ZipFile('data/application_test.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
application_test=pd.read_csv('data/application_test.csv')
os.remove('data/application_test.csv')

zip_ref=zp.ZipFile('data/sample_submission.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
sample_submission=pd.read_csv('data/sample_submission.csv')
os.remove('data/sample_submission.csv')

zip_ref=zp.ZipFile('data/application_train.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
application_train=pd.read_csv('data/application_train.csv')
os.remove('data/application_train.csv')

zip_ref=zp.ZipFile('data/bureau.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
bureau=pd.read_csv('data/bureau.csv')
os.remove('data/bureau.csv')

zip_ref=zp.ZipFile('data/bureau_balance.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
bureau_balance=pd.read_csv('data/bureau_balance.csv')
os.remove('data/bureau_balance.csv')

zip_ref=zp.ZipFile('data/previous_application.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
previous_application=pd.read_csv('data/previous_application.csv')
os.remove('data/previous_application.csv')

zip_ref=zp.ZipFile('data/credit_card_balance.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
credit_card_balance=pd.read_csv('data/credit_card_balance.csv')
os.remove('data/credit_card_balance.csv')

zip_ref=zp.ZipFile('data/POS_CASH_balance.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
POS_CASH_balance=pd.read_csv('data/POS_CASH_balance.csv')
os.remove('data/POS_CASH_balance.csv')

zip_ref=zp.ZipFile('data/installments_payments.csv.zip')
zip_ref.extractall('data/')
zip_ref.close()
installments_payments=pd.read_csv('data/installments_payments.csv')
os.remove('data/installments_payments.csv')


HomeCredit_columns_description=pd.read_csv('data/HomeCredit_columns_description.csv',encoding='Latin',index_col=0)

# %%
HomeCredit_columns_description=pd.read_csv('data/HomeCredit_columns_description.csv',encoding='Latin',index_col=0)

# %%
HomeCredit_columns_description
# Out:
#                             Table                         Row  \
# 1    application_{train|test}.csv                  SK_ID_CURR
# 2    application_{train|test}.csv                      TARGET
# 5    application_{train|test}.csv          NAME_CONTRACT_TYPE
# 6    application_{train|test}.csv                 CODE_GENDER
# 7    application_{train|test}.csv                FLAG_OWN_CAR
# 8    application_{train|test}.csv             FLAG_OWN_REALTY
# 9    application_{train|test}.csv                CNT_CHILDREN
# 10   application_{train|test}.csv            AMT_INCOME_TOTAL
# 11   application_{train|test}.csv                  AMT_CREDIT
# 12   application_{train|test}.csv                 AMT_ANNUITY
# 13   application_{train|test}.csv             AMT_GOODS_PRICE
# 14   application_{train|test}.csv             NAME_TYPE_SUITE
# 15   application_{train|test}.csv            NAME_INCOME_TYPE
# 16   application_{train|test}.csv         NAME_EDUCATION_TYPE
# ...

# %%
application_test.describe()
# Out:
#           SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# count   48744.000000  48744.000000      4.874400e+04  4.874400e+04
# mean   277796.676350      0.397054      1.784318e+05  5.167404e+05
# std    103169.547296      0.709047      1.015226e+05  3.653970e+05
# min    100001.000000      0.000000      2.694150e+04  4.500000e+04
# 25%    188557.750000      0.000000      1.125000e+05  2.606400e+05
# 50%    277549.000000      0.000000      1.575000e+05  4.500000e+05
# 75%    367555.500000      1.000000      2.250000e+05  6.750000e+05
# max    456250.000000     20.000000      4.410000e+06  2.245500e+06
#
#          AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# count   48720.000000     4.874400e+04                48744.000000
# mean    29426.240209     4.626188e+05                    0.021226
# std     16016.368315     3.367102e+05                    0.014428
# min      2295.000000     4.500000e+04                    0.000253
# ...

# %%
sample_submission
# Out:
#        SK_ID_CURR  TARGET
# 0          100001     0.5
# 1          100005     0.5
# 2          100013     0.5
# 3          100028     0.5
# 4          100038     0.5
# 5          100042     0.5
# 6          100057     0.5
# 7          100065     0.5
# 8          100066     0.5
# 9          100067     0.5
# 10         100074     0.5
# 11         100090     0.5
# 12         100091     0.5
# 13         100092     0.5
# 14         100106     0.5
# 15         100107     0.5
# 16         100109     0.5
# 17         100117     0.5
# 18         100128     0.5
# 19         100141     0.5
# 20         100150     0.5
# 21         100168     0.5
# 22         100169     0.5
# 23         100170     0.5
# 24         100171     0.5
# 25         100172     0.5
# 26         100184     0.5
# 27         100187     0.5
# 28         100212     0.5
# 29         100222     0.5
# ...           ...     ...
# 48714      455963     0.5
# 48715      455965     0.5
# 48716      456007     0.5
# ...

# %%
application_test.shape
# Out:
# (48744, 121)

# %%
application_train.shape
# Out:
# (307511, 122)

# %%
application_train
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 6           100009       0         Cash loans           F            Y
# 7           100010       0         Cash loans           M            Y
# 8           100011       0         Cash loans           F            N
# 9           100012       0    Revolving loans           M            N
# 10          100014       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# ...

# %%
application_test['TARGET']=3

# %%
application_test.shape
# Out:
# (48744, 122)

# %%
application_all=application_test+application_train

# %%
application_all.shape
# Out:
# (307511, 122)

# %%
#application_all=pd.get_dummies(application_all)

# %%
#application_all.shape

# %%
application_all.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 0 to 307510
# Data columns (total 122 columns):
# AMT_ANNUITY                     float64
# AMT_CREDIT                      float64
# AMT_GOODS_PRICE                 float64
# AMT_INCOME_TOTAL                float64
# AMT_REQ_CREDIT_BUREAU_DAY       float64
# AMT_REQ_CREDIT_BUREAU_HOUR      float64
# AMT_REQ_CREDIT_BUREAU_MON       float64
# AMT_REQ_CREDIT_BUREAU_QRT       float64
# AMT_REQ_CREDIT_BUREAU_WEEK      float64
# AMT_REQ_CREDIT_BUREAU_YEAR      float64
# APARTMENTS_AVG                  float64
# APARTMENTS_MEDI                 float64
# APARTMENTS_MODE                 float64
# BASEMENTAREA_AVG                float64
# BASEMENTAREA_MEDI               float64
# BASEMENTAREA_MODE               float64
# CNT_CHILDREN                    float64
# CNT_FAM_MEMBERS                 float64
# CODE_GENDER                     object
# COMMONAREA_AVG                  float64
# COMMONAREA_MEDI                 float64
# ...

# %%
application_all["CODE_GENDER"].value_counts()
# Out:
# FF      21487
# FM      11189
# MF      10515
# MM       5551
# FXNA        2
# Name: CODE_GENDER, dtype: int64

# %%
application_all["EMERGENCYSTATE_MODE"].value_counts()
# Out:
# NoNo      13636
# YesNo       202
# NoYes       177
# YesYes        1
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %%
application_all["FLAG_OWN_CAR"].value_counts()
# Out:
# NN    21266
# NY    11045
# YN    10865
# YY     5568
# Name: FLAG_OWN_CAR, dtype: int64

# %%
application_all["FLAG_OWN_REALTY"].value_counts()
# Out:
# YY    23396
# NY    10422
# YN    10262
# NN     4664
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
application_all["FONDKAPREMONT_MODE"].value_counts() #can drop
# Out:
# reg oper accountreg oper account              2992
# reg oper spec accountreg oper account          508
# reg oper accountreg oper spec account          450
# reg oper accountorg spec account               226
# org spec accountreg oper account               225
# not specifiedreg oper account                  220
# reg oper accountnot specified                  210
# reg oper spec accountreg oper spec account      66
# not specifiedreg oper spec account              43
# reg oper spec accountorg spec account           39
# reg oper spec accountnot specified              38
# org spec accountreg oper spec account           33
# not specifiedorg spec account                   21
# org spec accountnot specified                   20
# org spec accountorg spec account                13
# not specifiednot specified                      12
# Name: FONDKAPREMONT_MODE, dtype: int64

# %%
application_all["HOUSETYPE_MODE"].value_counts()#can drop
# Out:
# block of flatsblock of flats        12091
# specific housingblock of flats        151
# block of flatsspecific housing        131
# block of flatsterraced house          109
# terraced houseblock of flats           97
# terraced housespecific housing          2
# specific housingspecific housing        2
# terraced houseterraced house            1
# Name: HOUSETYPE_MODE, dtype: int64

# %%
application_all["NAME_CONTRACT_TYPE"].value_counts()
# Out:
# Cash loansCash loans              43741
# Cash loansRevolving loans          4564
# Revolving loansCash loans           396
# Revolving loansRevolving loans       43
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
application_all["NAME_EDUCATION_TYPE"].value_counts() #can drop or simplify
# Out:
# Secondary / secondary specialSecondary / secondary special    24170
# Higher educationSecondary / secondary special                  8860
# Secondary / secondary specialHigher education                  8263
# Higher educationHigher education                               3101
# Incomplete higherSecondary / secondary special                 1251
# Secondary / secondary specialIncomplete higher                 1107
# Secondary / secondary specialLower secondary                    437
# Higher educationIncomplete higher                               412
# Incomplete higherHigher education                               394
# Lower secondarySecondary / secondary special                    349
# Higher educationLower secondary                                 135
# Lower secondaryHigher education                                 110
# Incomplete higherIncomplete higher                               53
# Academic degreeSecondary / secondary special                     25
# ...

# %%
application_all["NAME_FAMILY_STATUS"].value_counts() #can drop or simplify
# Out:
# MarriedMarried                              20789
# MarriedSingle / not married                  4709
# Single / not marriedMarried                  4494
# MarriedCivil marriage                        3118
# Civil marriageMarried                        2751
# MarriedSeparated                             1993
# SeparatedMarried                             1851
# MarriedWidow                                 1674
# WidowMarried                                 1397
# Single / not marriedSingle / not married     1002
# Single / not marriedCivil marriage            716
# Civil marriageSingle / not married            656
# Single / not marriedSeparated                 459
# SeparatedSingle / not married                 445
# Civil marriageCivil marriage                  394
# Single / not marriedWidow                     365
# WidowSingle / not married                     319
# SeparatedCivil marriage                       273
# Civil marriageSeparated                       267
# ...

# %%
application_all["NAME_HOUSING_TYPE"].value_counts() #drop or simplfy
# Out:
# House / apartmentHouse / apartment        38743
# House / apartmentWith parents              2084
# With parentsHouse / apartment              1967
# House / apartmentMunicipal apartment       1632
# Municipal apartmentHouse / apartment       1433
# House / apartmentRented apartment           648
# Rented apartmentHouse / apartment           639
# House / apartmentOffice apartment           373
# Office apartmentHouse / apartment           358
# House / apartmentCo-op apartment            165
# Co-op apartmentHouse / apartment            107
# With parentsWith parents                    106
# With parentsMunicipal apartment              84
# Municipal apartmentWith parents              78
# Municipal apartmentMunicipal apartment       46
# With parentsRented apartment                 46
# Rented apartmentWith parents                 41
# Municipal apartmentRented apartment          34
# Rented apartmentMunicipal apartment          25
# Office apartmentWith parents                 23
# ...

# %%
application_all["NAME_INCOME_TYPE"].value_counts()
# Out:
# WorkingWorking                              12752
# Commercial associateWorking                  5852
# WorkingCommercial associate                  5694
# PensionerWorking                             4827
# WorkingPensioner                             4335
# Commercial associateCommercial associate     2628
# PensionerCommercial associate                2161
# Commercial associatePensioner                2098
# State servantWorking                         1887
# WorkingState servant                         1747
# PensionerPensioner                           1668
# Commercial associateState servant             821
# State servantCommercial associate             808
# PensionerState servant                        614
# State servantPensioner                        589
# State servantState servant                    248
# PensionerUnemployed                             2
# WorkingUnemployed                               2
# StudentWorking                                  2
# ...

# %%
application_all["NAME_TYPE_SUITE"].value_counts() # drop
# Out:
# UnaccompaniedUnaccompanied        32177
# UnaccompaniedFamily                5158
# FamilyUnaccompanied                4725
# UnaccompaniedSpouse, partner       1480
# Spouse, partnerUnaccompanied       1146
# FamilyFamily                        777
# UnaccompaniedChildren               428
# ChildrenUnaccompanied               334
# FamilySpouse, partner               221
# UnaccompaniedOther_B                212
# Spouse, partnerFamily               212
# Other_BUnaccompanied                164
# UnaccompaniedOther_A                104
# Other_AUnaccompanied                 82
# FamilyChildren                       68
# ChildrenFamily                       51
# Spouse, partnerSpouse, partner       49
# Group of peopleUnaccompanied         43
# Other_BFamily                        37
# UnaccompaniedGroup of people         28
# FamilyOther_B                        25
# FamilyOther_A                        23
# Spouse, partnerChildren              22
# ...

# %%
application_all["OCCUPATION_TYPE"].value_counts() #drop
# Out:
# LaborersLaborers                             1591
# Sales staffLaborers                           916
# LaborersSales staff                           879
# LaborersCore staff                            783
# Core staffLaborers                            739
# ManagersLaborers                              637
# LaborersManagers                              633
# Sales staffSales staff                        522
# DriversLaborers                               518
# LaborersDrivers                               515
# Sales staffCore staff                         485
# Core staffSales staff                         422
# ManagersSales staff                           374
# Core staffCore staff                          370
# Sales staffManagers                           343
# LaborersHigh skill tech staff                 338
# High skill tech staffLaborers                 338
# ManagersCore staff                            317
# Core staffManagers                            315
# ...

# %%
application_all["ORGANIZATION_TYPE"].value_counts() #drop
# Out:
# Business Entity Type 3Business Entity Type 3    2417
# XNABusiness Entity Type 3                       2057
# Business Entity Type 3XNA                       1884
# XNAXNA                                          1670
# Business Entity Type 3Self-employed             1377
# Self-employedBusiness Entity Type 3             1286
# XNASelf-employed                                1140
# Self-employedXNA                                1084
# Self-employedSelf-employed                       719
# OtherBusiness Entity Type 3                      593
# Business Entity Type 3Other                      567
# XNAOther                                         508
# OtherXNA                                         478
# Business Entity Type 3Medicine                   377
# MedicineBusiness Entity Type 3                   366
# Business Entity Type 3Business Entity Type 2     361
# OtherSelf-employed                               341
# XNABusiness Entity Type 2                        335
# ...

# %%
application_all["WALLSMATERIAL_MODE"].value_counts() #drop
# Out:
# PanelPanel                  2386
# PanelStone, brick           2381
# Stone, brickStone, brick    2264
# Stone, brickPanel           2233
# PanelBlock                   345
# Stone, brickBlock            334
# BlockPanel                   314
# BlockStone, brick            294
# PanelWooden                  193
# Stone, brickWooden           174
# WoodenPanel                  174
# WoodenStone, brick           160
# MixedPanel                    83
# Stone, brickMixed             77
# PanelMixed                    74
# PanelOthers                   73
# PanelMonolithic               70
# MixedStone, brick             65
# OthersStone, brick            65
# MonolithicStone, brick        61
# OthersPanel                   58
# MonolithicPanel               56
# Stone, brickMonolithic        54
# BlockBlock                    50
# Stone, brickOthers            48
# WoodenBlock                   26
# WoodenWooden                  22
# BlockWooden                   19
# ...

# %%
application_all["WEEKDAY_APPR_PROCESS_START"].value_counts() #drop
# Out:
# TUESDAYTUESDAY        1768
# TUESDAYMONDAY         1622
# TUESDAYTHURSDAY       1615
# TUESDAYFRIDAY         1597
# TUESDAYWEDNESDAY      1590
# MONDAYTUESDAY         1477
# WEDNESDAYTUESDAY      1475
# THURSDAYMONDAY        1475
# MONDAYWEDNESDAY       1470
# THURSDAYTUESDAY       1426
# THURSDAYWEDNESDAY     1421
# WEDNESDAYFRIDAY       1414
# WEDNESDAYWEDNESDAY    1393
# THURSDAYFRIDAY        1385
# MONDAYMONDAY          1383
# WEDNESDAYMONDAY       1381
# WEDNESDAYTHURSDAY     1361
# THURSDAYTHURSDAY      1359
# MONDAYTHURSDAY        1353
# MONDAYFRIDAY          1341
# FRIDAYTUESDAY         1270
# FRIDAYFRIDAY          1246
# FRIDAYMONDAY          1228
# FRIDAYWEDNESDAY       1190
# FRIDAYTHURSDAY        1190
# TUESDAYSATURDAY       1044
# WEDNESDAYSATURDAY      971
# THURSDAYSATURDAY       939
# MONDAYSATURDAY         924
# SATURDAYFRIDAY         811
# SATURDAYTHURSDAY       782
# SATURDAYTUESDAY        772
# FRIDAYSATURDAY         755
# SATURDAYMONDAY         755
# ...

# %%
application_all=application_all.drop(["WEEKDAY_APPR_PROCESS_START","WALLSMATERIAL_MODE","ORGANIZATION_TYPE","NAME_TYPE_SUITE","NAME_INCOME_TYPE","NAME_HOUSING_TYPE","NAME_FAMILY_STATUS","NAME_EDUCATION_TYPE","FONDKAPREMONT_MODE","HOUSETYPE_MODE","OCCUPATION_TYPE"],axis =1 )

# %%
application_all.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 0 to 307510
# Data columns (total 111 columns):
# AMT_ANNUITY                     float64
# AMT_CREDIT                      float64
# AMT_GOODS_PRICE                 float64
# AMT_INCOME_TOTAL                float64
# AMT_REQ_CREDIT_BUREAU_DAY       float64
# AMT_REQ_CREDIT_BUREAU_HOUR      float64
# AMT_REQ_CREDIT_BUREAU_MON       float64
# AMT_REQ_CREDIT_BUREAU_QRT       float64
# AMT_REQ_CREDIT_BUREAU_WEEK      float64
# AMT_REQ_CREDIT_BUREAU_YEAR      float64
# APARTMENTS_AVG                  float64
# APARTMENTS_MEDI                 float64
# APARTMENTS_MODE                 float64
# BASEMENTAREA_AVG                float64
# BASEMENTAREA_MEDI               float64
# BASEMENTAREA_MODE               float64
# CNT_CHILDREN                    float64
# CNT_FAM_MEMBERS                 float64
# CODE_GENDER                     object
# COMMONAREA_AVG                  float64
# COMMONAREA_MEDI                 float64
# ...

# %%
application_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 0 to 307510
# Columns: 111 entries, AMT_ANNUITY to YEARS_BUILD_MODE
# dtypes: float64(106), object(5)
# memory usage: 262.8+ MB

# %%
application_all=pd.get_dummies(application_all)

# %%
application_all.shape
# Out:
# (307511, 127)

# %%
application_test_new=application_all[application_all['TARGET']>3]
application_train_new=application_all[application_all['TARGET']==3]

# %%
application_test_new.shape
# Out:
# (3927, 127)

# %%
application_train_new.shape
# Out:
# (44817, 127)

# %%
application_train.shape
# Out:
# (307511, 122)
