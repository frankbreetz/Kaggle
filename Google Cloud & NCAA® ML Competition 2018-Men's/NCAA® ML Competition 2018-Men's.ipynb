# %%
import zipfile
from pathlib import Path
import pandas as pd
import os

data_path= Path('Data/')

sample_submission=pd.read_csv(data_path/'SampleSubmissionStage1.csv')

data_zip=data_path/'DataFiles.zip'
zip_ref = zipfile.ZipFile(data_zip, 'r')
data_csv_path=data_path/'DataFiles'
zip_ref.extractall(data_csv_path)
cities=pd.read_csv(data_csv_path/'Cities.csv')
os.remove(data_csv_path/'Cities.csv')
conferences=pd.read_csv(data_csv_path/'Conferences.csv')
os.remove(data_csv_path/'Conferences.csv')
team_conferences=pd.read_csv(data_csv_path/'TeamConferences.csv')
os.remove(data_csv_path/'TeamConferences.csv')
conference_tourney_games=pd.read_csv(data_csv_path/'ConferenceTourneyGames.csv')
os.remove(data_csv_path/'ConferenceTourneyGames.csv')
game_cites=pd.read_csv(data_csv_path/'GameCities.csv')
os.remove(data_csv_path/'GameCities.csv')
ncaa_tourney_compact_results=pd.read_csv(data_csv_path/'NCAATourneyCompactResults.csv')
os.remove(data_csv_path/'NCAATourneyCompactResults.csv')
ncaa_tourney_detailed_results=pd.read_csv(data_csv_path/'NCAATourneyDetailedResults.csv')
os.remove(data_csv_path/'NCAATourneyDetailedResults.csv')
ncaa_tourney_seed_round_slots=pd.read_csv(data_csv_path/'NCAATourneySeedRoundSlots.csv')
os.remove(data_csv_path/'NCAATourneySeedRoundSlots.csv')
ncaa_tourney_seeds=pd.read_csv(data_csv_path/'NCAATourneySeeds.csv')
os.remove(data_csv_path/'NCAATourneySeeds.csv')
ncaa_tourney_slots=pd.read_csv(data_csv_path/'NCAATourneySlots.csv')
os.remove(data_csv_path/'NCAATourneySlots.csv')
regular_season_compact_results=pd.read_csv(data_csv_path/'RegularSeasonCompactResults.csv')
os.remove(data_csv_path/'RegularSeasonCompactResults.csv')
regular_season_detailed_results=pd.read_csv(data_csv_path/'RegularSeasonDetailedResults.csv')
os.remove(data_csv_path/'RegularSeasonDetailedResults.csv')
seasons=pd.read_csv(data_csv_path/'Seasons.csv')
os.remove(data_csv_path/'Seasons.csv')
secondary_tourney_compact_results=pd.read_csv(data_csv_path/'SecondaryTourneyCompactResults.csv')
os.remove(data_csv_path/'SecondaryTourneyCompactResults.csv')
secondary_tourney_teams=pd.read_csv(data_csv_path/'SecondaryTourneyTeams.csv')
os.remove(data_csv_path/'SecondaryTourneyTeams.csv')
team_coaches=pd.read_csv(data_csv_path/'TeamCoaches.csv')
os.remove(data_csv_path/'TeamCoaches.csv')
teams=pd.read_csv(data_csv_path/'Teams.csv')
os.remove(data_csv_path/'Teams.csv')
#Below line has an encoding error
#team_spelling=pd.read_csv(data_csv_path/'TeamSpellings.csv')
os.remove(data_csv_path/'TeamSpellings.csv')
os.removedirs(data_csv_path)


Massey_Ordinals_zip=data_path/'MasseyOrdinals.zip'
zip_ref = zipfile.ZipFile(Massey_Ordinals_zip, 'r')
massey_ordinals_csv_path=data_path/'MasseyOrdinals'
zip_ref.extractall(massey_ordinals_csv_path)
massey_ordinals=pd.read_csv(massey_ordinals_csv_path/'MasseyOrdinals.csv')
os.remove(massey_ordinals_csv_path/'MasseyOrdinals.csv')
os.removedirs(massey_ordinals_csv_path)

PBP_2010_zip=data_path/'PlayByPlay_2010.zip'
zip_ref = zipfile.ZipFile(PBP_2010_zip, 'r')
PBP_2010_csv_path=data_path/'PlayByPlay_2010'
zip_ref.extractall(PBP_2010_csv_path)
events_2010=pd.read_csv(PBP_2010_csv_path/'Events_2010.csv')
os.remove(PBP_2010_csv_path/'Events_2010.csv')
players_2010=pd.read_csv(PBP_2010_csv_path/'Players_2010.csv')
os.remove(PBP_2010_csv_path/'Players_2010.csv')
os.removedirs(PBP_2010_csv_path)

PBP_2011_zip=data_path/'PlayByPlay_2011.zip'
zip_ref = zipfile.ZipFile(PBP_2011_zip, 'r')
PBP_2011_csv_path=data_path/'PlayByPlay_2011'
zip_ref.extractall(PBP_2011_csv_path)
events_2011=pd.read_csv(PBP_2011_csv_path/'Events_2011.csv')
os.remove(PBP_2011_csv_path/'Events_2011.csv')
players_2011=pd.read_csv(PBP_2011_csv_path/'Players_2011.csv')
os.remove(PBP_2011_csv_path/'Players_2011.csv')
os.removedirs(PBP_2011_csv_path)

PBP_2012_zip=data_path/'PlayByPlay_2012.zip'
zip_ref = zipfile.ZipFile(PBP_2012_zip, 'r')
PBP_2012_csv_path=data_path/'PlayByPlay_2012'
zip_ref.extractall(PBP_2012_csv_path)
events_2012=pd.read_csv(PBP_2012_csv_path/'Events_2012.csv')
os.remove(PBP_2012_csv_path/'Events_2012.csv')
players_2012=pd.read_csv(PBP_2012_csv_path/'Players_2012.csv')
os.remove(PBP_2012_csv_path/'Players_2012.csv')
os.removedirs(PBP_2012_csv_path)

PBP_2013_zip=data_path/'PlayByPlay_2013.zip'
zip_ref = zipfile.ZipFile(PBP_2013_zip, 'r')
PBP_2013_csv_path=data_path/'PlayByPlay_2013'
zip_ref.extractall(PBP_2013_csv_path)
events_2013=pd.read_csv(PBP_2013_csv_path/'Events_2013.csv')
os.remove(PBP_2013_csv_path/'Events_2013.csv')
players_2013=pd.read_csv(PBP_2013_csv_path/'Players_2013.csv')
os.remove(PBP_2013_csv_path/'Players_2013.csv')
os.removedirs(PBP_2013_csv_path)

PBP_2014_zip=data_path/'PlayByPlay_2014.zip'
zip_ref = zipfile.ZipFile(PBP_2014_zip, 'r')
PBP_2014_csv_path=data_path/'PlayByPlay_2014'
zip_ref.extractall(PBP_2014_csv_path)
events_2014=pd.read_csv(PBP_2014_csv_path/'Events_2014.csv')
os.remove(PBP_2014_csv_path/'Events_2014.csv')
players_2014=pd.read_csv(PBP_2014_csv_path/'Players_2014.csv')
os.remove(PBP_2014_csv_path/'Players_2014.csv')
os.removedirs(PBP_2014_csv_path)

PBP_2015_zip=data_path/'PlayByPlay_2015.zip'
zip_ref = zipfile.ZipFile(PBP_2015_zip, 'r')
PBP_2015_csv_path=data_path/'PlayByPlay_2015'
zip_ref.extractall(PBP_2015_csv_path)
events_2015=pd.read_csv(PBP_2015_csv_path/'Events_2015.csv')
os.remove(PBP_2015_csv_path/'Events_2015.csv')
players_2015=pd.read_csv(PBP_2015_csv_path/'Players_2015.csv')
os.remove(PBP_2015_csv_path/'Players_2015.csv')
os.removedirs(PBP_2015_csv_path)

PBP_2016_zip=data_path/'PlayByPlay_2016.zip'
zip_ref = zipfile.ZipFile(PBP_2016_zip, 'r')
PBP_2016_csv_path=data_path/'PlayByPlay_2016'
zip_ref.extractall(PBP_2016_csv_path)
events_2016=pd.read_csv(PBP_2016_csv_path/'Events_2016.csv')
os.remove(PBP_2016_csv_path/'Events_2016.csv')
players_2016=pd.read_csv(PBP_2016_csv_path/'Players_2016.csv')
os.remove(PBP_2016_csv_path/'Players_2016.csv')
os.removedirs(PBP_2016_csv_path)

PBP_2017_zip=data_path/'PlayByPlay_2017.zip'
zip_ref = zipfile.ZipFile(PBP_2017_zip, 'r')
PBP_2017_csv_path=data_path/'PlayByPlay_2017'
zip_ref.extractall(PBP_2017_csv_path)
events_2017=pd.read_csv(PBP_2017_csv_path/'Events_2017.csv')
os.remove(PBP_2017_csv_path/'Events_2017.csv')
players_2017=pd.read_csv(PBP_2017_csv_path/'Players_2017.csv')
os.remove(PBP_2017_csv_path/'Players_2017.csv')
os.removedirs(PBP_2017_csv_path)

# %%
massey_ordinals
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0          2003             35        SEL    1102          159
# 1          2003             35        SEL    1103          229
# 2          2003             35        SEL    1104           12
# 3          2003             35        SEL    1105          314
# 4          2003             35        SEL    1106          260
# 5          2003             35        SEL    1107          249
# 6          2003             35        SEL    1108          228
# 7          2003             35        SEL    1110          204
# 8          2003             35        SEL    1111          183
# 9          2003             35        SEL    1112           26
# 10         2003             35        SEL    1113           89
# 11         2003             35        SEL    1114          110
# 12         2003             35        SEL    1115          287
# 13         2003             35        SEL    1116          143
# 14         2003             35        SEL    1117          255
# 15         2003             35        SEL    1119          318
# 16         2003             35        SEL    1120           74
# 17         2003             35        SEL    1122          111
# 18         2003             35        SEL    1123           40
# 19         2003             35        SEL    1124           91
# 20         2003             35        SEL    1125          163
# 21         2003             35        SEL    1126          203
# 22         2003             35        SEL    1127          173
# 23         2003             35        SEL    1128          220
# 24         2003             35        SEL    1129          139
# 25         2003             35        SEL    1130           64
# 26         2003             35        SEL    1131           83
# 27         2003             35        SEL    1132          270
# 28         2003             35        SEL    1133          200
# 29         2003             35        SEL    1135          279
# ...         ...            ...        ...     ...          ...
# 3200171    2017            133        ZAM    1433           52
# 3200172    2017            133        ZAM    1434           96
# 3200173    2017            133        ZAM    1435           44
# 3200174    2017            133        ZAM    1436           64
# 3200175    2017            133        ZAM    1437            1
# 3200176    2017            133        ZAM    1438            3
# 3200177    2017            133        ZAM    1439           48
# 3200178    2017            133        ZAM    1440          324
# 3200179    2017            133        ZAM    1441          319
# 3200180    2017            133        ZAM    1442          296
# 3200181    2017            133        ZAM    1443          240
# 3200182    2017            133        ZAM    1444          163
# 3200183    2017            133        ZAM    1447          256
# 3200184    2017            133        ZAM    1448           34
# 3200185    2017            133        ZAM    1449          149
# 3200186    2017            133        ZAM    1450          188
# 3200187    2017            133        ZAM    1451          142
# 3200188    2017            133        ZAM    1452            6
# 3200189    2017            133        ZAM    1453          184
# 3200190    2017            133        ZAM    1454          233
# 3200191    2017            133        ZAM    1455           10
# 3200192    2017            133        ZAM    1456          154
# 3200193    2017            133        ZAM    1457          120
# 3200194    2017            133        ZAM    1458           14
# 3200195    2017            133        ZAM    1459          136
# 3200196    2017            133        ZAM    1460          175
# 3200197    2017            133        ZAM    1461          143
# 3200198    2017            133        ZAM    1462           39
# 3200199    2017            133        ZAM    1463          172
# 3200200    2017            133        ZAM    1464          283
#
# [3200201 rows x 5 columns]

# %%
ncaa_tourney_seed_round_slots
# Out:
#      Seed  GameRound GameSlot  EarlyDayNum  LateDayNum
# 0     W01          1     R1W1          136         137
# 1     W01          2     R2W1          138         139
# 2     W01          3     R3W1          143         144
# 3     W01          4     R4W1          145         146
# 4     W01          5     R5WX          152         152
# 5     W01          6     R6CH          154         154
# 6     W02          1     R1W2          136         137
# 7     W02          2     R2W2          138         139
# 8     W02          3     R3W2          143         144
# 9     W02          4     R4W1          145         146
# 10    W02          5     R5WX          152         152
# 11    W02          6     R6CH          154         154
# 12    W03          1     R1W3          136         137
# 13    W03          2     R2W3          138         139
# 14    W03          3     R3W2          143         144
# 15    W03          4     R4W1          145         146
# 16    W03          5     R5WX          152         152
# 17    W03          6     R6CH          154         154
# 18    W04          1     R1W4          136         137
# 19    W04          2     R2W4          138         139
# 20    W04          3     R3W1          143         144
# 21    W04          4     R4W1          145         146
# 22    W04          5     R5WX          152         152
# 23    W04          6     R6CH          154         154
# 24    W05          1     R1W5          136         137
# 25    W05          2     R2W4          138         139
# 26    W05          3     R3W1          143         144
# 27    W05          4     R4W1          145         146
# 28    W05          5     R5WX          152         152
# 29    W05          6     R6CH          154         154
# ..    ...        ...      ...          ...         ...
# 690  Z15a          4     R4Z1          145         146
# 691  Z15a          5     R5YZ          152         152
# 692  Z15a          6     R6CH          154         154
# 693  Z15b          0      Z15          134         135
# 694  Z15b          1     R1Z2          136         137
# 695  Z15b          2     R2Z2          138         139
# 696  Z15b          3     R3Z2          143         144
# 697  Z15b          4     R4Z1          145         146
# 698  Z15b          5     R5YZ          152         152
# 699  Z15b          6     R6CH          154         154
# 700   Z16          1     R1Z1          136         137
# 701   Z16          2     R2Z1          138         139
# 702   Z16          3     R3Z1          143         144
# 703   Z16          4     R4Z1          145         146
# 704   Z16          5     R5YZ          152         152
# 705   Z16          6     R6CH          154         154
# 706  Z16a          0      Z16          134         135
# 707  Z16a          1     R1Z1          136         137
# 708  Z16a          2     R2Z1          138         139
# 709  Z16a          3     R3Z1          143         144
# 710  Z16a          4     R4Z1          145         146
# 711  Z16a          5     R5YZ          152         152
# 712  Z16a          6     R6CH          154         154
# 5                    16         1244         634018     reb_def
# 6                    29         1244         634015    turnover
# 7                    31         1104         631928       steal
# 8                    33         1244         634009   foul_pers
# 9                    43         1104         631926  miss2_jump
# 10                   43         1244         634014     reb_def
# 11                   54         1244         634018  miss2_jump
# 12                   54         1104         631928     reb_def
# 13                   64         1244         634014   foul_pers
# 14                   64         1104         631925  miss1_free
# 15                   64         1104         631934    reb_dead
# 16                   64         1244         634009     reb_def
# 17                   67         1104         631925   foul_pers
# 18                   75         1104         631933       block
# 19                   75         1244         634019  miss2_jump
# 20                   75         1244         634020     reb_off
# 21                   91         1244         634009  miss3_jump
# 22                   91         1104         631925     reb_def
# 23                  109         1244         634018   foul_pers
# 24                  109         1104         631926  made1_free
# 25                  109         1104         631926  made1_free
# 26                  132         1104         631926   foul_pers
# 27                  132         1244         634018  miss1_free
# 28                  132         1244         634020    reb_dead
# 29                  132         1244         634018  made1_free
# ...                 ...          ...            ...         ...
# 2638249            2307         1314         635115  made3_jump
# 2638250            2310         1437         636951      sub_in
# 2638251            2310         1437         636944     sub_out
# 2638252            2310         1314         635117     timeout
# 2638253            2325         1437         636944      sub_in
# 2638254            2325         1437         636951     sub_out
# 2638255            2325         1437         636942    turnover
# 2638256            2334         1314         635109      assist
# 2638257            2334         1314         635112  made2_jump
# 2638258            2340         1437         636951      sub_in
# 2638259            2340         1437         636944     sub_out
# 2638260            2340         1437         636957     timeout
# 2638261            2365         1314         635108   foul_pers
# 2638262            2365         1437         636943  made1_free
# 2638263            2365         1437         636943  made1_free
# 2638264            2374         1314         635115   miss2_lay
# 2638265            2374         1314         635115     reb_off
# 2638266            2378         1314         635115   made2_lay
# 2638267            2387         1314         635112   foul_pers
# 2638268            2387         1437         636944      sub_in
# 2638269            2387         1437         636943     sub_out
# 2638270            2387         1437         636957     timeout
# 2638271            2387         1437         636950  made1_free
# 2638272            2387         1437         636950  made1_free
# 2638273            2395         1314         635115  made3_jump
# 2638274            2396         1437         636943      sub_in
# 2638275            2396         1437         636944     sub_out
# 2638276            2396         1437         636957     timeout
# 2638277            2400         1437         636942      assist
# 2638278            2400         1437         636951  made3_jump
#
# [2638279 rows x 11 columns]

# %%
regular_season_detailed_results
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0        2003      10     1104      68     1328      62    N      0    27
# 1        2003      10     1272      70     1393      63    N      0    26
# 2        2003      11     1266      73     1437      61    N      0    24
# 3        2003      11     1296      56     1457      50    N      0    18
# 4        2003      11     1400      77     1208      71    N      0    30
# 5        2003      11     1458      81     1186      55    H      0    26
# 6        2003      12     1161      80     1236      62    H      0    23
# 7        2003      12     1186      75     1457      61    N      0    28
# 8        2003      12     1194      71     1156      66    N      0    28
# 9        2003      12     1458      84     1296      56    H      0    32
# 10       2003      13     1166     106     1426      50    H      0    41
# 11       2003      13     1202      74     1106      73    N      0    29
# 12       2003      13     1237      66     1135      65    N      0    26
# 13       2003      13     1323      76     1125      48    H      0    25
# 14       2003      14     1125      83     1135      77    N      1    30
# 15       2003      14     1156      78     1236      71    N      0    27
# 16       2003      14     1161      81     1194      56    H      0    22
# 17       2003      14     1166      82     1202      57    H      0    33
# 18       2003      14     1183      73     1129      59    A      0    29
# 19       2003      14     1314      85     1336      55    H      0    32
# 20       2003      14     1323      89     1237      45    H      0    34
# 21       2003      14     1353      60     1162      36    H      0    23
# 22       2003      14     1390      61     1131      57    H      0    20
# 23       2003      14     1426      59     1106      47    N      0    25
# 24       2003      14     1462      87     1389      48    H      0    35
# 25       2003      15     1161      77     1156      63    H      0    27
# 26       2003      15     1194      93     1236      86    N      2    33
# 27       2003      15     1196      76     1256      55    H      0    28
# 28       2003      15     1242      81     1221      57    H      0    28
# 29       2003      15     1422      84     1447      65    H      0    33
# ...       ...     ...      ...     ...      ...     ...  ...    ...   ...
# 76606    2017     131     1153      81     1163      71    N      0    18
# 76607    2017     131     1181      75     1323      69    N      0    31
# 76608    2017     131     1235      80     1452      74    N      0    32
# 76609    2017     131     1245      70     1103      65    N      0    26
# 76610    2017     131     1246      79     1104      74    N      0    23
# 76611    2017     131     1276      84     1278      77    N      0    29
# 76612    2017     131     1292      83     1267      72    N      0    30
# 76613    2017     131     1300      67     1313      59    N      0    22
# 76614    2017     131     1305      79     1161      71    N      0    23
# 76615    2017     131     1308      70     1167      60    N      0    18
# 76616    2017     131     1309      68     1394      65    N      1    25
# 76617    2017     131     1315      93     1451      89    N      1    33
# 76618    2017     131     1343      72     1335      64    N      1    24
# 76619    2017     131     1348      84     1172      60    N      0    30
# 76620    2017     131     1374      70     1416      59    N      0    21
# 76621    2017     131     1402      83     1426      62    N      0    26
# 76622    2017     131     1407      74     1209      63    N      0    23
# 76623    2017     131     1411      53     1108      50    N      0    20
# 76624    2017     131     1413      50     1414      47    N      0    18
# 76625    2017     131     1433      87     1350      77    N      1    33
# 76626    2017     131     1436      56     1107      53    H      0    16
# 76627    2017     131     1437      74     1166      60    N      0    25
# 76628    2017     131     1458      76     1321      48    N      0    27
# 76629    2017     131     1463      73     1217      71    N      0    28
# 76630    2017     132     1246      82     1116      65    N      0    27
# 76631    2017     132     1276      71     1458      56    N      0    27
# 76632    2017     132     1343      71     1463      59    N      0    25
# 76633    2017     132     1348      70     1433      63    N      0    24
# 76634    2017     132     1374      71     1153      56    N      0    26
# 76635    2017     132     1407      59     1402      53    N      0    21
#
#        WFGA ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0        58 ...      10    16    22   10   22     8   18     9     2   20
# 1        62 ...      24     9    20   20   25     7   12     8     6   16
# 2        58 ...      26    14    23   31   22     9   12     2     5   23
# 3        38 ...      22     8    15   17   20     9   19     4     3   23
# 4        61 ...      16    17    27   21   15    12   10     7     1   14
# 5        57 ...      11    12    17    6   22     8   19     4     3   25
# 6        55 ...      15    20    28    9   21    11   30    10     4   28
# 7        62 ...      17    17    23    8   25    10   15    14     8   18
# 8        58 ...      18    12    27   13   26    13   25     8     2   18
# 9        67 ...      14     7    12    9   23    10   18     1     3   18
# 10       69 ...      11    12    17    8   15     8   17     7     3   15
# 11       51 ...      22     5     5   13   16    15   12     6     2   12
# 12       66 ...      19    11    17   14   21    17   18     8     4   13
# 13       56 ...      24     4     8   14   26    12   17    10     0   17
# 14       70 ...      15    17    27   20   27    17   24     7     7   19
# 15       46 ...      20    18    24    6   17    21   11     5     1   21
# 16       48 ...      13    12    19   16   18    10   16    15     3   36
# 17       61 ...      11     9    14   13   23     9   26     8     4   18
# 18       59 ...      14    14    18   12   22    10   23     4     5   14
# 19       60 ...      23    10    11   15   20     6   13     7     5   19
# 20       62 ...      15     5    11   27   22    10   17     6     3   23
# 21       57 ...       8     9    13   11   23     4   27     2     4   19
# 22       53 ...      17    16    18   11   22     7   14     7     0   24
# 23       53 ...      18     1     2    8   15    10    8    10     6   14
# 24       70 ...      20     1     4   16   18    11   19     4     3   16
# 25       58 ...      13    14    20    7   19    13   13     6     6   22
# 26       75 ...      31    18    22    9   33    20   26     6     7   25
# 27       48 ...       5    16    22   12   17    14   22     8     2   22
# 28       53 ...      21    14    21    8   22    11   20     9     3   27
# 29       53 ...      25    10    16   14   15     9   12    10     2   16
# ...     ... ...     ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 76606    47 ...      19    20    25   15   21     7    8     3     4   32
# 76607    51 ...      25     9    12   16   17    12    6     7     0   14
# 76608    59 ...      23     8    17    8   21    12   13     5     6   15
# 76609    49 ...      22     7    13   11   20    15   10     3     1   14
# 76610    44 ...      14    15    20   12   21    10   12     4     3   28
# 76611    54 ...      13    12    14   15   23    11   11     2     1   16
# 76612    56 ...      32     8    12   11   23    15   12     2     2   21
# 76613    56 ...      20     6     6   15   29    11   17     4     3   20
# 76614    55 ...      33     6    11    9   25     9    5     5     1   23
# 76615    39 ...      14    10    15   10   20    10   15    10     3   32
# 76616    59 ...      19    15    19    5   20    11   15     6     8   20
# 76617    69 ...      21    31    39    9   32    11   14     3     2   28
# 76618    64 ...      27     4     5    9   32    10   13     4     2   18
# 76619    61 ...      21    17    23    7   23    11   12     2     2   15
# 76620    46 ...      26     9    11    6   16     8   12     5     3   18
# 76621    49 ...      26    10    13   12   20     9   12     4     0   22
# 76622    54 ...      22    15    21   12   29     7   17     6     4   25
# 76623    51 ...      15     9    16   18   25     9   16     8     4   15
# 76624    52 ...      12     6     7    8   27     8   20     4     4   23
# 76625    67 ...      22    15    18    4   25    16   11     6     2   15
# 76626    48 ...      15     9    14    9   27    10    9     2     6   22
# 76627    54 ...      24     6     9   10   23    11   17     4     1   17
# 76628    57 ...      14     9    11    8   19     5   12     4     0   14
# 76629    59 ...      36     8    11   18   28    10    5     5     6   19
# 76630    56 ...      18    15    20    8   18     8   14     7     4   22
# 76631    48 ...      15     6     8   14   18    10   15     4     3   13
# 76632    52 ...      20    13    19   14   20    12    7     4     5   13
# 76633    54 ...      14    17    22   23   24     8    5     4     1   16
# 76634    52 ...      24    14    18   17   22     7    7     7     1   13
# 76635    60 ...      17     7     8    9   27    10   17     1     7   18
#
# [76636 rows x 34 columns]

# %%
list(regular_season_detailed_results)
# Out:
# ['Season',
#  'DayNum',
#  'WTeamID',
#  'WScore',
#  'LTeamID',
#  'LScore',
#  'WLoc',
#  'NumOT',
#  'WFGM',
#  'WFGA',
#  'WFGM3',
#  'WFGA3',
#  'WFTM',
#  'WFTA',
#  'WOR',
#  'WDR',
#  'WAst',
#  'WTO',
#  'WStl',
#  'WBlk',
#  'WPF',
#  'LFGM',
#  'LFGA',
#  'LFGM3',
#  'LFGA3',
#  'LFTM',
#  'LFTA',
#  'LOR',
#  'LDR',
#  'LAst',
#  'LTO',
#  'LStl',
#  'LBlk',
#  'LPF']

# %%
regular_season_detailed_results_2003=regular_season_detailed_results.loc[regular_season_detailed_results['Season']==2003]

len(regular_season_detailed_results_2003.loc[regular_season_detailed_results_2003['WTeamID']==1393])/(len(regular_season_detailed_results_2003.loc[regular_season_detailed_results_2003['WTeamID']==1393])+len(regular_season_detailed_results_2003.loc[regular_season_detailed_results_2003['LTeamID']==1393]))
# Out:
# 0.8275862068965517

# %%
#GetWinningPercentage(2013,1393)

# %%
def get_season(year):
    regular_season_detailed_results_year=regular_season_detailed_results.loc[regular_season_detailed_results['Season']==year]
    return regular_season_detailed_results_year

#def get_winning_percentage(year,team):
#    regular_season_detailed_results_year=get_season(year)
#    result=len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])/(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
#    return result
def add_seed1(row):
    year=row['Year']
    team=row['Team1']
    seed=(ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==year]).loc[ncaa_tourney_seeds['TeamID']==team]['Seed']
    if (seed.empty):
        seed='17'
    else:
        seed=str(seed)
        seed=seed[9:11]
        #seed=seed.str.slice(2,99)
    return str(seed)
def add_seed2(row):
    year=row['Year']
    team=row['Team2']
    seed=(ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==year]).loc[ncaa_tourney_seeds['TeamID']==team]['Seed']
    if (seed.empty):
        seed='17'
    else:
        seed=str(seed)
        seed=seed[9:11]
        #seed=seed.str.slice(2,99)
    return str(seed)
def get_winning_percentage1(row):
    regular_season_detailed_results_year=get_season(row['Year'])
    result=len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==row['Team1']])/(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==row['Team1']])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==row['Team1']]))
    return result
def get_winning_percentage2(row):
    regular_season_detailed_results_year=get_season(row['Year'])
    result=len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==row['Team2']])/(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==row['Team2']])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==row['Team2']]))
    return result

def get_ppg1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    total_points=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WScore'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LScore'])
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    ppg=total_points/games_played
    return ppg
def get_ppg2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    total_points=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WScore'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LScore'])
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    ppg=total_points/games_played
    return ppg

def get_3_point_percentage1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    total_3s_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM3'])
    total_3s_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGA3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGA3'])
    return total_3s_made/total_3s_attempted
def get_3_point_percentage2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    total_3s_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM3'])
    total_3s_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGA3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGA3'])
    return total_3s_made/total_3s_attempted

def get_field_goal_percentage1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    total_field_goals_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM'])
    total_field_goals_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGA'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGA'])
    return total_field_goals_made/total_field_goals_attempted
def get_field_goal_percentage2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    total_field_goals_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM'])
    total_field_goals_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGA'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGA'])
    return total_field_goals_made/total_field_goals_attempted

def get_free_throw_percentage1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    total_free_throw_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTM'])
    total_free_throws_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTA'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTA'])
    return total_free_throw_made/total_free_throws_attempted
def get_free_throw_percentage2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    total_free_throw_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTM'])
    total_free_throws_attempted=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTA'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTA'])
    return total_free_throw_made/total_free_throws_attempted


def get_field_goals_made_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    total_field_goals_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM'])
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    return total_field_goals_made/games_played
def get_field_goals_made_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    total_field_goals_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM'])
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    return total_field_goals_made/games_played

def get_3_points_made_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_3s_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM3'])
    return total_3s_made/games_played
def get_3_points_made_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_3s_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFGM3'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFGM3'])
    return total_3s_made/games_played


def get_free_throws_made_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_free_throws_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTM'])
    return total_free_throws_made/games_played
def get_free_throws_made_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_free_throws_made=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WFTM'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LFTM'])
    return total_free_throws_made/games_played

def get_off_rebounds_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_off_rebounds=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WOR'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LOR'])
    return total_off_rebounds/games_played
def get_off_rebounds_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_off_rebounds=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WOR'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LOR'])
    return total_off_rebounds/games_played

def get_def_rebounds_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_def_rebounds=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WDR'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LDR'])
    return total_def_rebounds/games_played
def get_def_rebounds_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_def_rebounds=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WDR'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LDR'])
    return total_def_rebounds/games_played


def get_assists_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_assists=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WAst'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LAst'])
    return total_assists/games_played
def get_assists_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_assists=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WAst'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LAst'])
    return total_assists/games_played

def get_turnovers_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_turnovers=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WTO'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LTO'])
    return total_turnovers/games_played
def get_turnovers_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_turnovers=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WTO'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LTO'])
    return total_turnovers/games_played

def get_steals_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_steals=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WStl'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LStl'])
    return total_steals/games_played
def get_steals_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_steals=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WStl'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LStl'])
    return total_steals/games_played

def get_blocks_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_blocks=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WBlk'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LBlk'])
    return total_blocks/games_played
def get_blocks_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_blocks=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WBlk'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LBlk'])
    return total_blocks/games_played

def get_fouls_per_game1(row):
    year=row['Year']
    team=row['Team1']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_fouls=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WPF'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LPF'])
    return total_fouls/games_played
def get_fouls_per_game2(row):
    year=row['Year']
    team=row['Team2']
    regular_season_detailed_results_year=get_season(year)
    games_played=(len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team])+len(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]))
    total_fouls=sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['WTeamID']==team]['WPF'])+sum(regular_season_detailed_results_year.loc[regular_season_detailed_results_year['LTeamID']==team]['LPF'])
    return total_fouls/games_played


#get_fouls_per_game(2009,1393)

# %%
#Get Training Data 
#this will be gotten through regular season games 
def get_training_data():
    training_data=pd.DataFrame()
    training_data['Team1']=regular_season_detailed_results[['WTeamID','LTeamID']].min(axis=1)
    training_data['Team2']=regular_season_detailed_results[['WTeamID','LTeamID']].max(axis=1)
    win=[]
    x=0
    for row in training_data['Team1']:
            if(row==regular_season_detailed_results['WTeamID'][x]):
                win.append(1)
            else:
                win.append(0)
            x=x+1
    training_data['Win']=win
    training_data['Year']=regular_season_detailed_results['Season']
    training_data['Ranking1']=training_data.apply( add_seed1,axis=1)
    training_data['Ranking2']=training_data.apply( add_seed2,axis=1)
    training_data['Ranking1']=training_data['Ranking1'].astype(int)
    training_data['Ranking2']=training_data['Ranking2'].astype(int)
    training_data['WP1']=training_data.apply( get_winning_percentage1,axis=1)
    training_data['WP2']=training_data.apply( get_winning_percentage2,axis=1)
    training_data['PPG1']=training_data.apply( get_winning_percentage1,axis=1)
    training_data['PPG2']=training_data.apply( get_ppg1,axis=1)
    training_data['3PPer1']=training_data.apply( get_3_point_percentage1,axis=1)
    training_data['3PPer2']=training_data.apply( get_3_point_percentage2,axis=1)
    training_data['FGPer1']=training_data.apply( get_field_goal_percentage1,axis=1)
    training_data['FGPer2']=training_data.apply( get_field_goal_percentage2,axis=1)
    training_data['FTPer1']=training_data.apply( get_free_throw_percentage1,axis=1)
    training_data['FTPer2']=training_data.apply( get_free_throw_percentage2,axis=1)
    training_data['FGPG1']=training_data.apply( get_field_goals_made_per_game1,axis=1)
    training_data['FGPG2']=training_data.apply( get_field_goals_made_per_game2,axis=1)
    training_data['3PPG1']=training_data.apply( get_3_points_made_per_game1,axis=1)
    training_data['3PPG2']=training_data.apply( get_3_points_made_per_game2,axis=1)
    training_data['FTPG1']=training_data.apply( get_free_throws_made_per_game1,axis=1)
    training_data['FTPG2']=training_data.apply( get_free_throws_made_per_game2,axis=1)
    training_data['ORPG1']=training_data.apply( get_off_rebounds_per_game1,axis=1)
    training_data['ORPG2']=training_data.apply( get_off_rebounds_per_game2,axis=1)
    training_data['DRPG1']=training_data.apply( get_def_rebounds_per_game1,axis=1)
    training_data['DRPG2']=training_data.apply( get_def_rebounds_per_game2,axis=1)
    training_data['APG1']=training_data.apply( get_assists_per_game1,axis=1)
    training_data['APG2']=training_data.apply( get_assists_per_game2,axis=1)
    training_data['TPG1']=training_data.apply( get_turnovers_per_game1,axis=1)
    training_data['TPG2']=training_data.apply( get_turnovers_per_game2,axis=1)
    training_data['SPG1']=training_data.apply( get_steals_per_game1,axis=1)
    training_data['SPG2']=training_data.apply( get_steals_per_game2,axis=1)
    training_data['BPG1']=training_data.apply( get_blocks_per_game1,axis=1)
    training_data['BPG2']=training_data.apply( get_blocks_per_game2,axis=1)
    training_data['PFPG1']=training_data.apply( get_fouls_per_game1,axis=1)
    training_data['PFPG2']=training_data.apply( get_fouls_per_game2,axis=1)
    
    return training_data
td=get_training_data()
#td=td.applymap(lambda x:)
#td['Team1WinningPercentage']=td.apply( get_winning_percentage,axis=1)
#td['Year'][0]
#td['Team1'][0]
#get_winning_percentage(2017,1402)
td
td.to_csv('new_csv.csv',index=False)

# %%
teams.loc[teams['TeamID']==1153]

# %%
import pandas as pd
td=pd.read_csv('new_csv.csv')
td['WP']=td['WP1']-td['WP2']
td['Ranking']=td['Ranking1']-td['Ranking2']
td['PPG']=td['PPG1']-td['PPG2']
td['3PPer']=td['3PPer1']-td['3PPer2']
td['FGPer']=td['FGPer1']-td['FGPer2']
td['FTPer']=td['FTPer1']=td['FTPer2']
td['FGPG']=td['FGPG1']-td['FGPG2']
td['3PPG']=td['3PPG1']-td['3PPG2']
td['FTPG']=td['FTPG1']-td['FTPG2']
td['ORPG']=td['ORPG1']-td['ORPG2']
td['DRPG']=td['DRPG1']-td['DRPG2']
td['APG']=td['APG1']-td['APG2']
td['TPG']=td['TPG1']-td['TPG2']
td['SPG']=td['SPG1']-td['SPG2']
td['BPG']=td['BPG1']-td['BPG2']
td['PFPG']=td['PFPG1']-td['PFPG2']
td=td.drop(['WP1','WP2','Ranking1','Ranking2','PPG1','PPG2','3PPer1','3PPer2','FGPer1','FGPer2','FTPer1','FTPer2','FGPG1','FGPG2','3PPG1','3PPG2','FTPG1','FTPG2','ORPG1','ORPG2','DRPG1','DRPG2','APG1','APG2','TPG1','TPG2','SPG1','SPG2','BPG1','BPG2','PFPG1','PFPG2'],axis=1)
td=td.drop(td.columns[0],axis=1)
td
# Out:
#        Team1  Team2  Win  Year        WP  Ranking        PPG     3PPer  \
# 0       1104   1328    1  2003 -0.192857        9 -68.678571 -0.073529
# 1       1272   1393    1  2003 -0.034483        4 -73.724138  0.018362
# 2       1266   1437    1  2003  0.321429      -14 -77.571429  0.030351
# 3       1296   1457    1  2003 -0.094470        0 -69.064516  0.031417
# 4       1208   1400    0  2003 -0.082011       16 -78.481481  0.031316
# 5       1186   1458    0  2003 -0.172414       12 -69.379310 -0.007706
# 6       1161   1236    1  2003  0.256322       -3 -73.433333  0.028659
# 7       1186   1457    1  2003 -0.056650        0 -69.379310 -0.000266
# 8       1156   1194    0  2003  0.044444        0 -65.366667  0.035820
# 9       1296   1458    0  2003 -0.210234       12 -69.064516  0.023977
# 10      1166   1426    1  2003  0.360269      -11 -78.363636  0.130498
# 11      1106   1202    0  2003  0.071429        0 -63.142857  0.018388
# 12      1135   1237    0  2003  0.013393        1 -73.357143  0.020641
# 13      1125   1323    0  2003 -0.138249       12 -71.892857 -0.013164
# 14      1125   1135    1  2003 -0.035714        0 -71.892857 -0.002645
# 15      1156   1236    1  2003 -0.043678        0 -65.366667  0.036615
# 16      1161   1194    1  2003  0.344444       -3 -73.433333  0.027863
# 17      1166   1202    1  2003  0.485931      -11 -78.363636  0.061287
# 18      1129   1183    0  2003 -0.035714        0 -65.464286 -0.081016
# 19      1314   1336    1  2003  0.281250        0 -70.625000  0.018941
# 20      1237   1323    0  2003 -0.115927       11 -70.656250 -0.031161
# 21      1162   1353    0  2003 -0.354497        0 -49.555556 -0.029842
# 22      1131   1390    0  2003 -0.075269       13 -67.433333 -0.018082
# 23      1106   1426    0  2003 -0.054233        0 -63.142857  0.087599
# 24      1389   1462    0  2003 -0.488506       14 -73.172414 -0.024241
# 25      1156   1161    0  2003 -0.300000        3 -65.366667  0.007957
# 26      1194   1236    1  2003 -0.088123        0 -68.851852  0.000795
# 27      1196   1256    1  2003  0.374194      -15 -75.129032  0.054139
# 28      1221   1242    0  2003  0.095402       12 -68.482759  0.020190
# 29      1422   1447    1  2003 -0.463134        2 -69.750000 -0.029803
# ...      ...    ...  ...   ...       ...      ...        ...       ...
# 76606   1153   1163    1  2017  0.384191      -11 -73.617647 -0.010294
# 76607   1181   1323    1  2017  0.036134       -3 -79.885714 -0.009563
# 76608   1235   1452    1  2017 -0.067736        1 -80.181818  0.040738
# 76609   1103   1245    0  2017  0.139929        3 -75.909091  0.055266
# 76610   1104   1246    0  2017 -0.277184       15 -68.090909 -0.035677
# 76607 -2.914286  1.844538 -1.262185  0.721008  3.204202
# 76608 -0.917112 -2.113191 -2.473262 -1.100713 -4.589127
# 76609  2.250446 -1.363636 -0.869875 -0.555258 -0.901070
# 76610 -4.105169  1.849376 -0.058824 -1.081996  0.433155
# 76611 -1.109091 -2.238095  0.215584 -4.016450 -1.764502
# 76612  1.381462  2.048128 -1.027629  1.122103  0.139037
# 76613  2.859140 -2.315054  0.802151 -1.991398 -3.639785
# 76614 -5.308824 -0.272059  0.705882 -0.915441  0.792279
# 76615 -0.809524  1.016667  3.383333  0.571429  3.792857
# 76616  2.500000  3.178571 -1.428571 -0.750000 -2.464286
# 76617  2.283333  2.219048  2.576190 -0.478571  3.461905
# 76618  0.500000  2.928571 -0.321429  0.392857  1.678571
# 76619  2.200758  0.975379 -1.269886 -2.778409 -2.660038
# 76620  5.040441 -3.803309  1.860294 -0.558824 -1.119485
# 76621 -0.838710 -1.741935 -1.032258  2.193548 -0.903226
# 76622 -0.368627  1.731373  0.884314  0.650980  2.845098
# 76623  0.590264  2.480730 -0.895538  0.128803  1.888438
# 76624  0.257576  0.672348  0.835227 -0.803030 -1.615530
# 76625  1.672794 -0.873162 -0.716912 -2.003676 -2.123162
# 76626 -0.666667  0.727273 -0.454545 -2.757576  1.757576
# 76627  2.948307  1.278966 -1.083779 -0.148841  2.430481
# 76628  1.735294 -0.441176 -1.852941  1.441176  3.294118
# 76629 -1.134615  0.096154  0.725275  0.329670  3.296703
# 76630 -1.441176 -0.294118  1.470588 -0.558824  1.294118
# 76631  0.270588 -1.542017 -0.939496 -0.787395 -0.621008
# 76632 -1.428571 -3.357143  1.357143 -1.107143  0.392857
# 76633 -1.840463 -1.317291 -1.165775  2.149733  0.349376
# 76634 -0.529412 -0.852941  1.735294  1.647059  1.558824
# 76635  2.022770 -0.622391  0.117647  0.907970  0.411765
#
# [76636 rows x 20 columns]

# %%
X=td.drop(['Win','Team1','Team2','Year'],axis=1)
y=td['Win']

# %%
#Scaling made gradient descent better,but XGBoost worse
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler = StandardScaler()
X_scaled=scaler.fit_transform(X.astype(np.float64))

# %%
#need to make the 60 60000 when you go back to the full csv
X_train,X_test,y_train,y_test=X_scaled[:60000],X_scaled[60000:],y[:60000],y[60000:]

# %%
import numpy as np
shuffle_index=np.random.permutation(60000)
X_train,y_train=X_train[shuffle_index],y_train[shuffle_index]

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf=SGDClassifier(random_state=42,loss='log')
sgd_clf.fit(X_train,y_train)
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clf,X_train,y_train,cv=3,scoring='neg_log_loss')
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([-0.54823331, -0.55276299, -0.53341988])

# %%
from sklearn.model_selection import GridSearchCV
cross_val_score(xgb_clf,X_train,y_train,cv=3,scoring='neg_log_loss')
param_grid=[
    {'max_depth':[2,3,4],'learning_rate':[0.1],'n_estimators':[100],'booster':['gblinear'],'n_jobs':[1],'gamma':[0,0.01,0.1],'min_child_weight':[1,2,3],'max_delta_step':[0,1,2],'reg_alpha':[0,0.01,0.1],'reg_lambda':[0.9,1,1.1],'scale_pos_weight':[0.9,1,1.1],'base_score':[0.5]},
               ]
grid_search=GridSearchCV(xgb_clf,param_grid,cv=3,scoring='neg_log_loss')
grid_search.fit(X_train,y_train)
print('best params'+grid_search.best_params_)

print(grid_search.best_estimator_)
cvres=grid_search.cv_results_
for score,params in zip(cvres['mean_test_score'],cvres['params']):
    print(score,params)
#from sklearn.base import BaseEstimator

#class NeverWin(BaseEstimator):
#    def fit(self,X,y=None):
#        pass
#    def predict(self,X):
#        return np.zeros((len(X),1),dtype=bool)

# %%
#never_5_clf=NeverWin()
#cross_val_score(never_5_clf,X_train,y_train,cv=3,scoring='accuracy')

# %%
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(sgd_clf,X_train,y_train,cv=3)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train,y_train_pred)
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([[23059,  7523],
#        [ 8945, 20473]])

# %%
from sklearn.metrics import precision_score,recall_score
precision_score(y_train,y_train_pred)
# Out:
# 0.73128304043434778

# %%
recall_score(y_train,y_train_pred)
# Out:
# 0.69593446189407848

# %%
from sklearn.metrics import f1_score
f1_score(y_train,y_train_pred)
# Out:
# 0.71317100358797514

# %%
y_scores=cross_val_predict(sgd_clf,X_train,y_train,cv=3,method='decision_function')
from sklearn.metrics import precision_recall_curve
precisions,recalls,thresholds=precision_recall_curve(y_train,y_scores)
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/frank/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
def plot_precision_recall_vs_threshold(precisions,recalls,thresholds):
    plt.plot(thresholds,precisions[:-1],'b--',label='Precision')
    plt.plot(thresholds,recalls[:-1],'g-',label='Recall')
    plt.xlabel('Threshold')
    plt.legend(loc='upper left')
    plt.ylim([0,1])

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plot_precision_recall_vs_threshold(precisions,recalls,thresholds)
plt.show()

# %%
from sklearn.metrics import roc_curve
fpr,tpr,thresholds=roc_curve(y_train,y_scores)
def plot_roc_curve(fpr,tpr,label=None):
    plt.plot(fpr,tpr,linewidth=2,label=label)
    plt.plot([0,1],[0,1],'k--')
    plt.axis([0,1,0,1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    
plot_roc_curve(fpr,tpr)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_train,y_scores)
# Out:
# 0.80182465417128834

# %%
from sklearn.ensemble import RandomForestClassifier
forest_clf = RandomForestClassifier(random_state=42)
#y_probas_forest=cross_val_predict(forest_clf,X_train,y_train,cv=3,method='neg_log_loss')
cross_val_score(forest_clf,X_train,y_train,cv=10,scoring='neg_log_loss')
# Out:
# array([-1.74122141, -1.85054988, -1.89230239, -1.98563902, -1.90106664,
#        -2.018071  , -2.01029199, -1.99449047, -1.84245823, -2.03138452])

# %%
y_scores_forest=y_probas_forest[:,1]#score=proba of positive class
fpr_forest,tpr_forest,threshold_forest=roc_curve(y_train,y_scores_forest)

# %%
plt.plot(fpr,tpr,"b",label='SGC')
plot_roc_curve(fpr_forest,tpr_forest,'Random Forest')
plt.legend(loc='bottom right')
plt.show()
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:638: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
roc_auc_score(y_train,y_scores_forest)
# Out:
# 0.73753194696800528

# %%
predictions_forest,recalls_forest,thresholds_forest=precision_recall_curve(y_train,y_scores_forest)
plot_precision_recall_vs_threshold(predictions_forest,recalls_forest,thresholds_forest)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(forest_clf,X_train,y_train,cv=3,scoring='neg_log_loss')
# Out:
# array([-1.68765136, -1.70935468, -1.71517749])

# %%
from xgboost import XGBClassifier
xgb_clf=XGBClassifier(base_score= 0.5,
 booster= 'gblinear',
 gamma= 0,
 learning_rate= 0.1,
 max_delta_step= 0,
 max_depth= 2,
 min_child_weight= 1,
 n_estimators= 100,
 n_jobs= 1,
 reg_alpha= 0,
 reg_lambda= 0.9,
 scale_pos_weight= 1)
y_probas_xgb=cross_val_predict(xgb_clf,X_train,y_train,cv=3,method='predict_proba')

# %%
y_scores_xgb=y_probas_xgb[:,1]#score=proba of positive class
fpr_xgb,tpr_xgb,threshold_xgb=roc_curve(y_train,y_scores_xgb)

# %%
plt.plot(fpr,tpr,"b",label='SGC')
plot_roc_curve(fpr_forest,tpr_forest,'Random Forest')
plot_roc_curve(fpr_xgb,tpr_xgb,'XGBoost')
plt.legend(loc='bottom right')
plt.show()
# Out:
# /home/frank/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:638: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
from sklearn.model_selection import GridSearchCV
cross_val_score(xgb_clf,X_train,y_train,cv=3,scoring='neg_log_loss')
param_grid=[
    {'max_depth':[2,3,4],'learning_rate':[0.1],'n_estimators':[100],'booster':['gblinear'],'n_jobs':[1],'gamma':[0,0.01,0.1],'min_child_weight':[1,2,3],'max_delta_step':[0,1,2],'reg_alpha':[0,0.01,0.1],'reg_lambda':[0.9,1,1.1],'scale_pos_weight':[0.9,1,1.1],'base_score':[0.5]},
               ]
grid_search=GridSearchCV(xgb_clf,param_grid,cv=3,scoring='neg_log_loss')
grid_search.fit(X_train,y_train)
grid_search.best_params_
# Out:
# {'base_score': 0.5,
#  'booster': 'gblinear',
#  'gamma': 0,
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 2,
#  'min_child_weight': 1,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'reg_alpha': 0,
#  'reg_lambda': 0.9,
#  'scale_pos_weight': 1}

# %%
print(grid_search.best_estimator_)
cvres=grid_search.cv_results_
for score,params in zip(cvres['mean_test_score'],cvres['params']):
    print(score,params)
#cross_val_score(forest_clf,X_train,y_train,cv=3,scoring='accuracy')
#param_grid=[
#    {'max_features':[2,4,6,8]},
#    {'bootstrap':[False],'max_features':[2,3,4]},
#           ]
#grid_search=GridSearchCV(forest_clf,param_grid,cv=3,scoring='accuracy')
#grid_search.fit(X_train,y_train)
#grid_search.best_params_
# Out:
# XGBClassifier(base_score=0.5, booster='gblinear', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=0.9, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# ...
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144822792 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204193304 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974123855 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144875975 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204243069 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974172241 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144929156 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204292907 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974220637 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.510144826344 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204196969 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974128768 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144879665 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204246626 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.5099741765 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144932759 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204297073 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974223807 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.01, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}
# -0.51014485612 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 0.9}
# -0.509204233141 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1}
# -0.509974164074 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 0.9, 'scale_pos_weight': 1.1}
# -0.510144909126 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 0.9}
# -0.509204283214 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1}
# -0.509974212811 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1, 'scale_pos_weight': 1.1}
# -0.510144962571 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 0.9}
# -0.509204332372 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1}
# -0.509974260651 {'base_score': 0.5, 'booster': 'gblinear', 'gamma': 0.1, 'learning_rate': 0.1, 'max_delta_step': 2, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 0.1, 'reg_lambda': 1.1, 'scale_pos_weight': 1.1}

# %%
print((ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==1985]).loc[ncaa_tourney_seeds['TeamID']==1000]['Seed'])
print(ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==1985])
# Out:
# Series([], Name: Seed, dtype: object)
#     Season Seed  TeamID
# 0     1985  W01    1207
# 1     1985  W02    1210
# 2     1985  W03    1228
# 3     1985  W04    1260
# 4     1985  W05    1374
# 5     1985  W06    1208
# 6     1985  W07    1393
# 7     1985  W08    1396
# 8     1985  W09    1439
# 9     1985  W10    1177
# 10    1985  W11    1455
# 11    1985  W12    1330
# 12    1985  W13    1233
# 13    1985  W14    1318
# 14    1985  W15    1273
# 15    1985  W16    1250
# 16    1985  X01    1385
# 17    1985  X02    1433
# 18    1985  X03    1301
# 19    1985  X04    1424
# 20    1985  X05    1449
# 21    1985  X06    1409
# 22    1985  X07    1104
# 23    1985  X08    1234
# 24    1985  X09    1116
# 25    1985  X10    1112
# 26    1985  X11    1431
# 27    1985  X12    1246
# 28    1985  X13    1361
# 29    1985  X14    1305
# ..     ...  ...     ...
# 34    1985  Y03    1181
# 35    1985  Y04    1326
# 36    1985  Y05    1256
# 37    1985  Y06    1403
# 38    1985  Y07    1412
# 39    1985  Y08    1425
# 40    1985  Y09    1229
# 41    1985  Y10    1277
# 42    1985  Y11    1130
# 43    1985  Y12    1338
# 44    1985  Y13    1235
# 45    1985  Y14    1337
# 46    1985  Y15    1335
# 47    1985  Y16    1299
# 48    1985  Z01    1276
# 49    1985  Z02    1314
# 50    1985  Z03    1242
# 51    1985  Z04    1261
# 52    1985  Z05    1268
# 53    1985  Z06    1345
# 54    1985  Z07    1323
# 55    1985  Z08    1437
# 56    1985  Z09    1173
# 57    1985  Z10    1333
# 58    1985  Z11    1120
# 59    1985  Z12    1275
# 60    1985  Z13    1298
# 61    1985  Z14    1325
# 62    1985  Z15    1292
# 63    1985  Z16    1192
#
# [64 rows x 3 columns]

# %%
seed=(ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==1985]).loc[ncaa_tourney_seeds['TeamID']==1207]['Seed']
if (seed.empty):
        seed=17
else:
    seed

# %%
str(seed[0])
# Out:
# 'W01'

# %%
#td=td.drop(['Ranking1'])
td['Ranking1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ranking1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-bec3ea2c23eb> in <module>()
#       1 #td=td.drop(['Ranking1'])
# ----> 2 td['Ranking1'].value_counts()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ranking1'

# %%
td.info()

# %%
td.to_csv('new_csv.csv')

# %%
import numpy as np
new_index=np.arange(64)

foo=ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==2014].sort_values(by=['TeamID'])
foo=foo.reset_index(drop=True)
foo

# %% [markdown]
# #### for x in range(0,)

# %%
Team1=[]
Team2=[]
Year=[]
z=0
for w in range(2014,2018):
    foo=ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==w].sort_values(by=['TeamID'])
    foo=foo.reset_index(drop=True)
    for x in range(0,len(foo)):
        for y in range(x+1,len(foo)):
            #TestData1985.append([z,foo.loc[x]['TeamID'],foo.loc[y]['TeamID']])
            Team1.append(foo.loc[x]['TeamID'])
            Team2.append(foo.loc[y]['TeamID'])
            Year.append(foo.loc[x]['Season'])
            #TestData1985[z]['Team1']=foo.loc[x]['TeamID']
            #TestData1985[z]['Team2']=foo.loc[y]['TeamID']
            z=z+1

# %%
FinalData=pd.DataFrame()
FinalData['Team1']=Team1
FinalData['Team2']=Team2
FinalData['Year']=Year

# %%
FinalData

# %%
def get_final_data():
    Team1=[]
    Team2=[]
    Year=[]
    for w in range(2014,2018):
        foo=ncaa_tourney_seeds.loc[ncaa_tourney_seeds['Season']==w].sort_values(by=['TeamID'])
        foo=foo.reset_index(drop=True)
        for x in range(0,len(foo)):
            for y in range(x+1,len(foo)):
                Team1.append(foo.loc[x]['TeamID'])
                Team2.append(foo.loc[y]['TeamID'])
                Year.append(foo.loc[x]['Season'])
    final_data=pd.DataFrame()
    final_data['Team1']=Team1
    final_data['Team2']=Team2
    final_data['Year']=Year
    final_data['Ranking1']=final_data.apply( add_seed1,axis=1)
    final_data['Ranking2']=final_data.apply( add_seed2,axis=1)
    final_data['Ranking1']=final_data['Ranking1'].astype(int)
    final_data['Ranking2']=final_data['Ranking2'].astype(int)
    final_data['WP1']=final_data.apply( get_winning_percentage1,axis=1)
    final_data['WP2']=final_data.apply( get_winning_percentage2,axis=1)
    final_data['PPG1']=final_data.apply( get_winning_percentage1,axis=1)
    final_data['PPG2']=final_data.apply( get_ppg1,axis=1)
    final_data['3PPer1']=final_data.apply( get_3_point_percentage1,axis=1)
    final_data['3PPer2']=final_data.apply( get_3_point_percentage2,axis=1)
    final_data['FGPer1']=final_data.apply( get_field_goal_percentage1,axis=1)
    final_data['FGPer2']=final_data.apply( get_field_goal_percentage2,axis=1)
    final_data['FTPer1']=final_data.apply( get_free_throw_percentage1,axis=1)
    final_data['FTPer2']=final_data.apply( get_free_throw_percentage2,axis=1)
    final_data['FGPG1']=final_data.apply( get_field_goals_made_per_game1,axis=1)
    final_data['FGPG2']=final_data.apply( get_field_goals_made_per_game2,axis=1)
    final_data['3PPG1']=final_data.apply( get_3_points_made_per_game1,axis=1)
    final_data['3PPG2']=final_data.apply( get_3_points_made_per_game2,axis=1)
    final_data['FTPG1']=final_data.apply( get_free_throws_made_per_game1,axis=1)
    final_data['FTPG2']=final_data.apply( get_free_throws_made_per_game2,axis=1)
    final_data['ORPG1']=final_data.apply( get_off_rebounds_per_game1,axis=1)
    final_data['ORPG2']=final_data.apply( get_off_rebounds_per_game2,axis=1)
    final_data['DRPG1']=final_data.apply( get_def_rebounds_per_game1,axis=1)
    final_data['DRPG2']=final_data.apply( get_def_rebounds_per_game2,axis=1)
    final_data['APG1']=final_data.apply( get_assists_per_game1,axis=1)
    final_data['APG2']=final_data.apply( get_assists_per_game2,axis=1)
    final_data['TPG1']=final_data.apply( get_turnovers_per_game1,axis=1)
    final_data['TPG2']=final_data.apply( get_turnovers_per_game2,axis=1)
    final_data['SPG1']=final_data.apply( get_steals_per_game1,axis=1)
    final_data['SPG2']=final_data.apply( get_steals_per_game2,axis=1)
    final_data['BPG1']=final_data.apply( get_blocks_per_game1,axis=1)
    final_data['BPG2']=final_data.apply( get_blocks_per_game2,axis=1)
    final_data['PFPG1']=final_data.apply( get_fouls_per_game1,axis=1)
    final_data['PFPG2']=final_data.apply( get_fouls_per_game2,axis=1)
    return final_data

# %%
fd=get_final_data()

# %%
fd

# %%
fd.to_csv('final_data.csv')

# %%
fd=pd.read_csv('final_data.csv')

# %%
import pandas as pd
fd=pd.read_csv('final_data.csv')
fd['WP']=fd['WP1']-fd['WP2']
fd['Ranking']=fd['Ranking1']-fd['Ranking2']
fd['PPG']=fd['PPG1']-fd['PPG2']
fd['3PPer']=fd['3PPer1']-fd['3PPer2']
fd['FGPer']=fd['FGPer1']-fd['FGPer2']
fd['FTPer']=fd['FTPer1']=fd['FTPer2']
fd['FGPG']=fd['FGPG1']-fd['FGPG2']
fd['3PPG']=fd['3PPG1']-fd['3PPG2']
fd['FTPG']=fd['FTPG1']-fd['FTPG2']
fd['ORPG']=fd['ORPG1']-fd['ORPG2']
fd['DRPG']=fd['DRPG1']-fd['DRPG2']
fd['APG']=fd['APG1']-fd['APG2']
fd['TPG']=fd['TPG1']-fd['TPG2']
fd['SPG']=fd['SPG1']-fd['SPG2']
fd['BPG']=fd['BPG1']-fd['BPG2']
fd['PFPG']=fd['PFPG1']-fd['PFPG2']
fd=fd.drop(['WP1','WP2','Ranking1','Ranking2','PPG1','PPG2','3PPer1','3PPer2','FGPer1','FGPer2','FTPer1','FTPer2','FGPG1','FGPG2','3PPG1','3PPG2','FTPG1','FTPG2','ORPG1','ORPG2','DRPG1','DRPG2','APG1','APG2','TPG1','TPG2','SPG1','SPG2','BPG1','BPG2','PFPG1','PFPG2'],axis=1)
fd=fd.drop(fd.columns[0],axis=1)
#fd_scaled=

# %%
xgb_clf.fit(X,y)
anser=xgb_clf.predict_proba(fd.drop(['Team1','Team2','Year'],axis=1))

# %%
answer=pd.DataFrame(data=anser)

# %%
submit=pd.DataFrame()
submit['ID']=fd['Year'].astype(str)+'_'+fd['Team1'].astype(str)+'_'+fd['Team2'].astype(str)
submit['Pred']=answer[1]

# %%
submit.to_csv('Submission.csv',index=False)
